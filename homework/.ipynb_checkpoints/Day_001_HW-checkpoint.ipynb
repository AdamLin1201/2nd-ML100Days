# %% [markdown]
# ## 作業1 ：

# %% [markdown]
# ### 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：

# %% [markdown]
#  一. 你選的這組資料為何重要？
#    * Ans: 是否能從新聞去預測股價

# %% [markdown]
#  二. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)？
#    * Ans: 由Intrinio提供

# %% [markdown]
# 三. 蒐集而來的資料型態為何？
#   * Ans: csv檔

# %% [markdown]
# 四. 這組資料想解決的問題如何評估？
#  * Ans: XGboost

# %% [markdown]
# ## 作業2 ：

# %% [markdown]
# ### 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：

# %% [markdown]
# 一. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#    * 提升業績比較直覺的想法就是提升載客流量，那如何提升載客流量就需要試想各種可能，假設天氣、乘車地點、車流量、時間等等，都需要考慮進去。

# %% [markdown]
# 二. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#  * 利用叫車系統或是紀錄收集過往的資訊，以及從googlemap、氣象局等等收集所需要的資訊

# %% [markdown]
# 三. 蒐集而來的資料型態為何
#  * 具結構化的資料、可能有數值及文字

# %% [markdown]
# 四. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#  * 在採用新的方式執行一段時間之後(三個月或更久)，利用這段時間的資料和過往的資料作比較，或許能用F1 score。

# %% [markdown]
# ## 作業3 ：

# %% [markdown]
# 請寫一個函式用來計算 Mean Square Error
#
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, y1):
    """
    請完成這個 Function 後往下執行
    """
    mse = sum((y-y1)**2/len(y))
    return mse

# %%
def mean_absolute_error(y, y1):
    """
    請完成這個 Function 後往下執行
    """
    mae = sum(abs(y-y1)/len(y))
    
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 199.500
# The Mean absolute error is 11.507
